# %% [markdown]
# # **KOMPRESI CITRA METODE HUFFMAN**

# %% [markdown]
# **Upload File Citra**
#
# > Citra Warna "10 citra .JPG, 10 citra .PNG, 10 citra .BMP "

# %% [markdown]
# **![alt text](https://pemrogramanmatlab.files.wordpress.com/2016/06/ruang-warna-citra-rgb.jpg)**

# %%
#Upload file citra 1x runtime
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-171648f6-80fc-4f7f-bb88-c09148ba269f" name="files[]" multiple disabled />
#      <output id="result-171648f6-80fc-4f7f-bb88-c09148ba269f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.bmp to 1.bmp

# %%
#Upload file citra 1x runtime
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-63f4499f-8469-4775-a012-fdd4e905b958" name="files[]" multiple disabled />
#      <output id="result-63f4499f-8469-4775-a012-fdd4e905b958">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.bmp to 1.bmp
# Saving 1.jpg to 1.jpg
# Saving 1.png to 1.png
# Saving 2.bmp to 2.bmp
# Saving 2.jpg to 2.jpg
# Saving 2.png to 2.png
# Saving 3.bmp to 3.bmp
# Saving 3.jpg to 3.jpg
# Saving 3.png to 3.png
# Saving 4.bmp to 4.bmp
# Saving 4.jpg to 4.jpg
# Saving 4.png to 4.png
# Saving 5.bmp to 5.bmp
# Saving 5.jpg to 5.jpg
# Saving 5.png to 5.png
# Saving 5rev.png to 5rev.png
# Saving 5rev2.png to 5rev2.png
# Saving 6.bmp to 6.bmp
# Saving 6.jpg to 6.jpg
# Saving 6.png to 6.png
# Saving 7.bmp to 7.bmp
# Saving 7.jpg to 7.jpg
# Saving 7.png to 7.png
# Saving 7rev.png to 7rev.png
# Saving 8.bmp to 8.bmp
# Saving 8.jpg to 8.jpg
# Saving 8.png to 8.png
# Saving 9.bmp to 9.bmp
# Saving 9.jpg to 9.jpg
# Saving 9.png to 9.png
# Saving 10.bmp to 10.bmp
# Saving 10.jpg to 10.jpg
# Saving 10.png to 10.png

# %% [markdown]
# **Import Library**
#
# > " import library python yang akan digunakan "

# %%
#import library
import imageio
import numpy as np
import matplotlib.pyplot as plt
from operator import itemgetter, attrgetter
import queue
import cv2

# %% [markdown]
# **Fungsi dan class**

# %%
#function2
#binary tree, cek https://medium.com/quick-code/binary-tree-traversal-python-implementation-f69c405bb286
class Node:
	def __init__(self):
		self.prob = None
		self.code = None
		self.data = None
		self.left = None
		self.right = None 	# the color (the bin value) is only required in the leaves
	def __lt__(self, other):
		if (self.prob < other.prob):		# define rich comparison methods for sorting in the priority queue
			return 1
		else:
			return 0
	def __ge__(self, other):
		if (self.prob > other.prob):
			return 1
		else:
			return 0 

#fungsi ubah citra rgb ke gray    
def rgb2gray(img):
	gray_img = np.rint(img[:,:,0]*0.2989 + img[:,:,1]*0.5870 + img[:,:,2]*0.1140)
	gray_img = gray_img.astype(int)
	return gray_img

#fungsi tree
def tree(probabilities):
	prq = queue.PriorityQueue()
	for color,probability in enumerate(probabilities):
		leaf = Node()
		leaf.data = color
		leaf.prob = probability
		prq.put(leaf)

	while (prq.qsize()>1):
		newnode = Node()		# create new node
		l = prq.get()
		r = prq.get()			# get the smalles probs in the leaves
						# remove the smallest two leaves
		newnode.left = l 		# left is smaller
		newnode.right = r
		newprob = l.prob+r.prob	# the new prob in the new node must be the sum of the other two
		newnode.prob = newprob
		prq.put(newnode)	# new node is inserted as a leaf, replacing the other two 
	return prq.get()		# return the root node - tree is complete
	
#fungsi huffman
def huffman_traversal(root_node,tmp_array,f):		# traversal of the tree to generate codes
	if (root_node.left is not None):
		tmp_array[huffman_traversal.count] = 1
		huffman_traversal.count+=1
		huffman_traversal(root_node.left,tmp_array,f)
		huffman_traversal.count-=1
	if (root_node.right is not None):
		tmp_array[huffman_traversal.count] = 0
		huffman_traversal.count+=1
		huffman_traversal(root_node.right,tmp_array,f)
		huffman_traversal.count-=1
	else:
		huffman_traversal.output_bits[root_node.data] = huffman_traversal.count		#count the number of bits for each color
		bitstream = ''.join(str(cell) for cell in tmp_array[1:huffman_traversal.count]) 
		color = str(root_node.data)
		wr_str = color+' '+ bitstream+'\n'
		f.write(wr_str)		# write the color and the code to a file
	return

# %% [markdown]
# **Proses Main Program**
#
# > " Proses kompresi huffman dimulai dari olah citra, kompresi dan hasil"

# %%
# open citra yang akan di kompresi
img = imageio.imread('1.bmp')

# preprocesing
# convert ke grayscale image
gray_img = rgb2gray(img)

# compute histogram of pixels
hist = np.bincount(gray_img.ravel(),minlength=256)

probabilities = hist/np.sum(hist)		# a priori probabilities from frequencies

root_node = tree(probabilities)			# create the tree using the probs.
tmp_array = np.ones([65],dtype=int)
huffman_traversal.output_bits = np.empty(256,dtype=int) 
huffman_traversal.count = 0
f = open('codes.txt','w')
huffman_traversal(root_node,tmp_array,f)		# traverse the tree and write the codes

input_bits = img.shape[0]*img.shape[1]*8	# calculate number of bits in grayscale 
outpuut = (1-np.sum(huffman_traversal.output_bits*hist)/input_bits)
compression = (outpuut)*100	# compression rate
#compression = (1-np.sum(huffman_traversal.output_bits*hist)/input_bits)*100	# compression rate
print('Besar file citra : ')
print('_____________________________')
print('Sebelum kompresi ',input_bits)
print('Sesudah kompresi ',np.sum(huffman_traversal.output_bits*hist))
print('Besar Kompresi adalah ',compression,' %')
# Out:
# Besar file citra :
# _____________________________
# Sebelum kompresi  1784160
# Sesudah kompresi  1611724
# Besar Kompresi adalah  9.664828266523184  %

# %% [markdown]
# **Cek MSE**
#
# > " Fungsi untuk menghitung MSE "

# %% [markdown]
# ![alt text](https://radiokuantum.files.wordpress.com/2017/07/render.png)

# %%
#MSE THINKKKKK!!!!!!!!
import numpy as np 
  
# Given values 
Y_true = (input_bits)  # Y_true = Y (original values) 
  
# Calculated values 
out=sum(huffman_traversal.output_bits*hist)
Y_pred = (out)  # Y_pred = Y' 
  
# Mean Squared Error 
MSE = np.square(np.subtract(Y_true,Y_pred)).mean() 
print('Besar citra sebelum kompresi = ',Y_true)
print('Besar citra sesudah kompresi = ',Y_pred)
print('Hasil MSE dari citra sebelum kompresi vs sesudah kompresi = ','{:06.2f}'.format(MSE))
# Out:
# Besar citra sebelum kompresi =  1784160
# Besar citra sesudah kompresi =  1611724
# Hasil MSE dari citra sebelum kompresi vs sesudah kompresi =  29734174096.00

# %% [markdown]
# **Cek PSNR**
#
# > " Fungsi untuk menghitung PSNR "

# %% [markdown]
# ![alt text](https://radiokuantum.files.wordpress.com/2017/07/render-1.png)

# %%
#import lib tambahan
import math
asli =(input_bits)
out=sum(huffman_traversal.output_bits*hist)
kompres = (out)
def psnr(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
      return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

d=psnr(asli,kompres)
print("Nilai PSNR Citra asli vs kompres adalah : ",abs(d))
# Out:
# Nilai PSNR Citra asli vs kompres adalah :  56.601755190606696
